# %%
import os
from dotenv import load_dotenv
load_dotenv(".env")

import pymongo

USER_MONGODB = os.environ.get("MONGO_DB_USER")
PASSWORD_MONGODB = os.environ.get("MONGO_DB_PASSWORD")

uri = f"mongodb+srv://yossrSafa:azerty12@projet.ic795xi.mongodb.net/"
client = pymongo.mongo_client.MongoClient(uri)
db = client['app_auth']

# %%
#Création de la collection user_table
user_collection=db["user_table"]
user_collection_schema = {
    "firstname",
    "lastname",
    "email",
    "username",
    "password",
    "created_at" 
}

#Création de la collection user_email_verification_table
user_email_verification_collection=db["user_email_verification_table"]
user_email_verification_schema = {
    "user_id",
    "verified_at" 
}

#Création de la collection session_table
session_collection=db["session_table"]
session_collection_schema = {
    "user_id",
    "connected_at" 
}

# %%
import psycopg2
USER_PSQL = os.environ.get("POSTGRESQL_LOCAL_USER")
PASSWORD_PSQL = os.environ.get("POSTGRESQL_LOCAL_PASSWORD")
db_name = "course"
conn = psycopg2.connect(user="postgres", password="yassouraGH21",dbname="App_auth", host="localhost", port="5432")
cur = conn.cursor()
cur.execute("SELECT * FROM user_table")
user_data = cur.fetchall()
mongo_docs = [
        dict(zip(user_collection_schema, row)) for row in user_data
    ]
user_collection.insert_many(mongo_docs)
""" Insertion les données dans la table user_email_verification_table"""

cur.execute("SELECT * FROM user_email_verification_table")
user_data = cur.fetchall()
mongo_docs = [
        dict(zip(user_email_verification_schema, row)) for row in user_data
    ]
user_email_verification_collection.insert_many(mongo_docs)
""" Insertion les données dans la table  session_table"""

cur.execute("SELECT * FROM session_table")
user_data = cur.fetchall()
mongo_docs = [
        dict(zip(session_collection_schema, row)) for row in user_data
    ]
session_collection.insert_many(mongo_docs)


cur.close()
conn.close()

# %%
from pymongo import MongoClient
USER_PSQL = os.environ.get("POSTGRESQL_LOCAL_USER")
PASSWORD_PSQL = os.environ.get("POSTGRESQL_LOCAL_PASSWORD")
db_name = "course"
conn = psycopg2.connect(user="postgres", password="yassouraGH21",dbname="App_auth", host="localhost", port="5432")
cur = conn.cursor()
souscription_collection=db["subscription"]
def migrate_subscription():
    souscription_collection_schema = {
        "subscription_id",
        "subscribed_at",
        "user_id",
        "paid",
        "subscription_plan",
        }
    cur.execute("SELECT * FROM subscription")
    subscriptions = cur.fetchall()
    mongo_docs = [
        dict(zip(souscription_collection_schema, row)) for row in user_data
        ]
    souscription_collection.insert_many(mongo_docs)


cur.close()
conn.close()
client.close()
